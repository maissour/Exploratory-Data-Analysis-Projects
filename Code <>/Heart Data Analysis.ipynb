# %% [markdown]
# # Working on real Project with Python

# %% [markdown]
# ## Heart DataSet

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
heart=pd.read_csv('your path of csv file')

# %% [markdown]
# ### THe head and shape of Data

# %%
heart.shape
# Out:
# (303, 14)

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ### Q1) Show the number of nan value in dataframe

# %%
heart.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ### Q2) Put description and information about data

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
heart.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# #### minimum age is 29
# #### maximum age is 77
# #### which means the data contains adults

# %% [markdown]
# ### Q3) Percentage of men and women in data

# %%
men=heart[heart['sex']==1]
len(men)
# Out:
# 207

# %%
women=heart[heart['sex']==0]
len(women)
# Out:
# 96

# %%
PoM=(len(men)/(len(heart['sex'])))*100
print('the Percentage of men in data : {:.2f}%'.format(PoM))
# Out:
# the Percentage of men in data : 68.32%

# %%
PoW=(len(women)/(len(heart['sex'])))*100
print('the Percentage of men in data : {:.2f}%'.format(PoW))
# Out:
# the Percentage of men in data : 31.68%

# %%
import seaborn as sns
sns.countplot(x='sex', data=heart, palette="mako_r")
plt.xlabel("Sex (0 = female, 1= male)")
plt.show()

# %% [markdown]
# ### Q4) How many men and women have heart disease?

# %%
Phds=heart[heart['target']==1]

# %%
Phds.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
Phds.groupby('sex')['target'].count()
len(Phds['sex'])
# Out:
# 165

# %%
sns.countplot(x="target", data=heart, palette="Accent")
plt.show()

# %%
Phds.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  165.000000  165.000000  165.000000  165.000000  165.000000  165.000000
# mean    52.496970    0.563636    1.375758  129.303030  242.230303    0.139394
# std      9.550651    0.497444    0.952222   16.169613   53.552872    0.347412
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     44.000000    0.000000    1.000000  120.000000  208.000000    0.000000
# 50%     52.000000    1.000000    2.000000  130.000000  234.000000    0.000000
# 75%     59.000000    1.000000    2.000000  140.000000  267.000000    0.000000
# max     76.000000    1.000000    3.000000  180.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  165.000000  165.000000  165.000000  165.000000  165.000000  165.000000
# mean     0.593939  158.466667    0.139394    0.583030    1.593939    0.363636
# ...

# %% [markdown]
# ### Q5) How many 29 year old men or women have HD?

# %%
Phds[Phds['age']==29]
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 72   29    1   1       130   204    0        0      202      0      0.0
#
#     slope  ca  thal  target
# 72      2   0     2       1

# %% [markdown]
# ### Q6) Percentage of men and women with a fbs greater than 120 mg/dL

# %%
sns.countplot(x='fbs', data=Phds)
plt.xlabel("fbs")
plt.show()

# %%
Phds[Phds['fbs']==1]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 8     52    1   2       172   199    1        1      162      0      0.5
# 14    58    0   3       150   283    1        0      162      0      1.0
# 23    61    1   2       150   243    1        1      137      1      1.0
# 26    59    1   2       150   212    1        1      157      0      1.6
# 28    65    0   2       140   417    1        0      157      0      0.8
# 29    53    1   2       130   197    1        0      152      0      1.2
# 36    54    0   2       135   304    1        1      170      0      0.0
# 60    71    0   2       110   265    1        0      130      0      0.0
# 64    58    1   2       140   211    1        0      165      0      0.0
# 76    51    1   2       125   245    1        0      166      0      2.4
# 78    52    1   1       128   205    1        1      184      0      0.0
# ...

# %%
len(Phds[Phds['fbs']==1])
# Out:
# 23

# %%
#Men with fbs greater than 120 mg/dl
Phds[(Phds['fbs']==1) & (Phds['sex']==1)]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 8     52    1   2       172   199    1        1      162      0      0.5
# 23    61    1   2       150   243    1        1      137      1      1.0
# 26    59    1   2       150   212    1        1      157      0      1.6
# 29    53    1   2       130   197    1        0      152      0      1.2
# 64    58    1   2       140   211    1        0      165      0      0.0
# 76    51    1   2       125   245    1        0      166      0      2.4
# 78    52    1   1       128   205    1        1      184      0      0.0
# 83    52    1   3       152   298    1        1      178      0      1.2
# 87    46    1   1       101   197    1        1      156      0      0.0
# 90    48    1   2       124   255    1        1      175      0      0.0
# 97    52    1   0       108   233    1        1      147      0      0.1
# ...

# %%
Phds[(Phds['fbs']==1) & (Phds['sex']==1)].shape
# Out:
# (17, 14)

# %%
len(Phds[(Phds['fbs']==1) & (Phds['sex']==1)])
# Out:
# 17

# %%
#Women with fbs greater than 120 mg/dl
Phds[(Phds['fbs']==1) & (Phds['sex']==0)]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 14    58    0   3       150   283    1        0      162      0      1.0
# 28    65    0   2       140   417    1        0      157      0      0.8
# 36    54    0   2       135   304    1        1      170      0      0.0
# 60    71    0   2       110   265    1        0      130      0      0.0
# 93    54    0   1       132   288    1        0      159      1      0.0
# 136   60    0   2       120   178    1        1       96      0      0.0
#
#      slope  ca  thal  target
# 14       2   0     2       1
# 28       2   1     2       1
# 36       2   0     2       1
# 60       2   1     2       1
# 93       2   1     2       1
# 136      2   0     2       1

# %%
fb1=(len(Phds[(Phds['fbs']==1) & (Phds['sex']==1)])/len(Phds[Phds['fbs']==1]))*100
print('Percentage of men with a fbs greater than 120 mg/dL : {:.2f}%'.format(fb1))
# Out:
# Percentage of men with a fbs greater than 120 mg/dL : 73.91%

# %%
fb0=(len(Phds[(Phds['fbs']==1) & (Phds['sex']==0)])/len(Phds[Phds['fbs']==1]))*100
print('Percentage of women with a fbs greater than 120 mg/dL : {:.2f}%'.format(fb0))
# Out:
# Percentage of women with a fbs greater than 120 mg/dL : 26.09%

# %% [markdown]
# ### Q7) How many men or women with a chol greater than 200 mg/dl and have HD

# %%
Phds[Phds['chol']>200]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 156   47    1   2       130   253    0        1      179      0      0.0
# 158   58    1   1       125   220    0        1      144      0      0.4
# 159   56    1   1       130   221    0        0      163      0      0.0
# 160   56    1   1       120   240    0        1      169      0      0.0
# 161   55    0   1       132   342    0        1      166      0      1.2
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
len(Phds[Phds['chol']>200])
# Out:
# 135

# %%
print('the men who have HD and chol greater than 200 mg/dl')
len(Phds[(Phds['chol']>200) & (Phds['sex']==1)])
# Out:
# the men who have HD and chol greater than 200 mg/dl
# 75

# %%
print('the women who have HD and chol greater than 200 mg/dl')
len(Phds[(Phds['chol']>200) & (Phds['sex']==0)])
# Out:
# the women who have HD and chol greater than 200 mg/dl
# 60

# %% [markdown]
# ### Q8) What is the highest 'maximum heart rate achieved' in men and women who have HD?

# %%
Phds['thalach'].sort_values(ascending=False)
# Out:
# 72     202
# 103    194
# 125    192
# 62     190
# 32     188
#       ...
# 48     115
# 17     114
# 95     111
# 139    105
# 136     96
# Name: thalach, Length: 165, dtype: int64

# %%
Phds['thalach'].max()
# Out:
# 202

# %% [markdown]
# ### Q9) How many men and women have yes for 'exercise induced angina'

# %%
Phds[(Phds['exang']==1) & (Phds['sex']==1)]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 13    64    1   3       110   211    0        0      144      1      1.8
# 21    44    1   2       130   233    0        1      179      1      0.4
# 23    61    1   2       150   243    1        1      137      1      1.0
# 24    40    1   3       140   199    0        1      178      1      1.4
# 34    51    1   3       125   213    0        0      125      1      1.4
# 42    45    1   0       104   208    0        0      148      1      3.0
# 66    51    1   2       100   222    0        1      143      1      1.2
# 71    51    1   2        94   227    0        1      154      1      0.0
# 73    51    1   0       140   261    0        0      186      1      0.0
# 77    59    1   1       140   221    0        1      164      1      0.0
# 79    58    1   2       105   240    0        0      154      1      0.6
# 91    57    1   0       132   207    0        1      168      1      0.0
# ...

# %%
len(Phds[(Phds['exang']==1) & (Phds['sex']==1)])
# Out:
# 15

# %%
Phds[(Phds['exang']==1) & (Phds['sex']==0)]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 4     57    0   0       120   354    0        1      163      1      0.6
# 35    46    0   2       142   177    0        0      160      1      1.4
# 93    54    0   1       132   288    1        0      159      1      0.0
# 107   45    0   0       138   236    0        0      152      1      0.2
# 110   64    0   0       180   325    0        1      154      1      0.0
# 119   46    0   0       138   243    0        0      152      1      0.0
# 122   41    0   2       112   268    0        0      172      1      0.0
# 129   74    0   1       120   269    0        0      121      1      0.2
#
#      slope  ca  thal  target
# 4        2   0     2       1
# 35       0   0     2       1
# 93       2   1     2       1
# 107      1   0     2       1
# 110      2   0     2       1
# 119      1   0     2       1
# 122      2   0     2       1
# 129      2   1     2       1

# %%
len(Phds[(Phds['exang']==1) & (Phds['sex']==0)])
# Out:
# 8
